# %% [markdown]
# ## Requirements env + moduls

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# !cd yolov5
# !pip install -r requirements.txt  # install
# !pip install ultralytics
# !pip install clearml
# !pip install pillow==11.0.0 
# !pip install requests==2.32.3 
# !pip install setuptools==75.6.0 
# !pip install tqdm==4.67.1
# !pip install -U ipywidgets
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 32.58 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Collecting ultralytics
#   Downloading ultralytics-8.3.73-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2024.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.73-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.6/914.6 kB 16.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.73 ultralytics-thop-2.0.14
# Collecting clearml
#   Downloading clearml-1.17.1-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: attrs>=18.0 in /opt/conda/lib/python3.10/site-packages (from clearml) (23.2.0)
# Collecting furl>=2.0.0 (from clearml)
#   Downloading furl-2.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /opt/conda/lib/python3.10/site-packages (from clearml) (4.20.0)
# Requirement already satisfied: numpy>=1.10 in /opt/conda/lib/python3.10/site-packages (from clearml) (1.26.4)
# Collecting pathlib2>=2.3.0 (from clearml)
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: Pillow>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from clearml) (9.5.0)
# Requirement already satisfied: psutil>=3.4.2 in /opt/conda/lib/python3.10/site-packages (from clearml) (5.9.3)
# Requirement already satisfied: pyparsing>=2.0.3 in /opt/conda/lib/python3.10/site-packages (from clearml) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.10/site-packages (from clearml) (2.8.2)
# Requirement already satisfied: PyYAML>=3.12 in /opt/conda/lib/python3.10/site-packages (from clearml) (6.0.1)
# Requirement already satisfied: requests>=2.20.0 in /opt/conda/lib/python3.10/site-packages (from clearml) (2.31.0)
# Requirement already satisfied: six>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from clearml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from clearml) (1.26.18)
# Requirement already satisfied: pyjwt<2.10.0,>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from clearml) (2.8.0)
# Requirement already satisfied: referencing<0.40 in /opt/conda/lib/python3.10/site-packages (from clearml) (0.32.1)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from furl>=2.0.0->clearml) (1.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6.0->clearml) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6.0->clearml) (0.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20.0->clearml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20.0->clearml) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.20.0->clearml) (2024.2.2)
# Downloading clearml-1.17.1-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.4 MB/s eta 0:00:00
# Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Installing collected packages: pathlib2, furl, clearml
# Successfully installed clearml-1.17.1 furl-2.1.3 pathlib2-2.3.7.post1
# Collecting pillow==11.0.0
#   Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 43.3 MB/s eta 0:00:00
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.5.0
#     Uninstalling Pillow-9.5.0:
#       Successfully uninstalled Pillow-9.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed pillow-11.0.0
# Collecting requests==2.32.3
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests==2.32.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests==2.32.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests==2.32.3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests==2.32.3) (2024.2.2)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.8.1 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.2 which is incompatible.
# gcsfs 2023.12.2.post1 requires fsspec==2023.12.2, but you have fsspec 2024.2.0 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-pubsub 2.19.0 requires grpcio<2.0dev,>=1.51.3, but you have grpcio 1.51.1 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed requests-2.32.3
# Collecting setuptools==75.6.0
#   Downloading setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
# Downloading setuptools-75.6.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.3 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.0.3
#     Uninstalling setuptools-69.0.3:
#       Successfully uninstalled setuptools-69.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.0.5 which is incompatible.
# Successfully installed setuptools-75.6.0
# Collecting tqdm==4.67.1
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.5 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# keras-nlp 0.8.1 requires keras-core, which is not installed.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.2 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed tqdm-4.67.1
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (7.7.1)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 3.3 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 8.0 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 45.6 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
import torch
from IPython import display
from IPython.display import clear_output
from pathlib import Path
import yaml
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
import io
import os
import cv2
import json
import shutil
import numpy as np
from sklearn.model_selection import train_test_split
from glob import glob
from tqdm import tqdm
# %matplotlib inline

# %%
IMAGES_PATH = "/kaggle/input/birdies/images"
LABELS_PATH = "/kaggle/input/birdies/labels"

labels = os.listdir(LABELS_PATH)

# Split data
train, test = train_test_split(labels, test_size=0.2, shuffle=True)
valid, test = train_test_split(test, test_size=0.2)

print(f"train: {len(train)}; test: {len(test)}; valid: {len(valid)}") #valid: {len(valid)}
# Out:
# train: 1608; test: 81; valid: 321

# %%
def move_files_to_dir(files, dirname):
    for label_filename in tqdm(files, total = len(files)):
        image_filename = f"{label_filename[:-4]}.jpg"
        shutil.copy(f"{IMAGES_PATH}/{image_filename}", f"{dirname}/images/{image_filename}")
        shutil.copy(f"{LABELS_PATH}/{label_filename}", f"{dirname}/labels/{label_filename}")


# Make folders
if not os.path.exists("test/images"):
    os.makedirs("test/images")
if not os.path.exists("test/labels"):
    os.makedirs("test/labels")
if not os.path.exists("train/images"):
    os.makedirs("train/images")
if not os.path.exists("train/labels"):
    os.makedirs("train/labels")
if not os.path.exists("valid/images"):
    os.makedirs("valid/images")
if not os.path.exists("valid/labels"):
    os.makedirs("valid/labels")

# Move splits to folders
move_files_to_dir(train, "train")
move_files_to_dir(test, "test")
move_files_to_dir(valid, "valid")

# Path
train_path = "../train/images"
test_path = "../test/images"
valid_path = "../valid/images"
# Out:
# 100%|██████████| 1608/1608 [00:21<00:00, 73.81it/s]
# 100%|██████████| 81/81 [00:01<00:00, 77.96it/s]
# 100%|██████████| 321/321 [00:03<00:00, 84.23it/s]

# %% [markdown]
# ## Make Yaml

# %%
with open("data.yaml", "w") as file:
    yaml.dump({
        "train": train_path,
        "test": test_path,
        "val": valid_path,
        "names": ['birds'],
        "nc": 1,
        #"names": [f'{name}' for name in names]
    } , stream=file, default_flow_style=None)

print("Now we are ready to train yolov5 model")
! ls
# Out:
# Now we are ready to train yolov5 model
# __notebook__.ipynb  data.yaml  test  train  valid  yolov5

# %% [markdown]
# ## Train

# %%
PROJECT_NAME = "birds"
BASE_MODEL = "yolov5m6.pt"
BATCH = 64
TRAIN_EPOCHS = 40
#VAL_BATCH = 64

# %%
! python yolov5/train.py --batch $BATCH --img 600 --epochs $TRAIN_EPOCHS --data "data.yaml" --weights $BASE_MODEL --project $PROJECT_NAME --name 'feature_extraction' --cache --freeze 12
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-08 12:17:40.528614: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-08 12:17:40.528759: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-08 12:17:40.736909: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5m6.pt, cfg=, data=data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=64, imgsz=600, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=birds, name=feature_extraction, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[12], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: Ultralytics requirement ['thop>=0.1.1'] not found, attempting AutoUpdate...
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from thop>=0.1.1) (2.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->thop>=0.1.1) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->thop>=0.1.1) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->thop>=0.1.1) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->thop>=0.1.1) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->thop>=0.1.1) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->thop>=0.1.1) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->thop>=0.1.1) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->thop>=0.1.1) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238
#
# requirements: AutoUpdate success ✅ 7.9s, installed 1 package: ['thop>=0.1.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir birds', view at http://localhost:6006/
# ClearML: WARNING ⚠️ ClearML is installed but not configured, skipping ClearML logging. See https://docs.ultralytics.com/yolov5/tutorials/clearml_logging_integration#readme
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 16.4MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m6.pt to yolov5m6.pt...
# 100%|██████████████████████████████████████| 69.0M/69.0M [00:00<00:00, 83.9MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   1991808  models.common.Conv                      [384, 576, 3, 2]
#   8                -1  2   2327040  models.common.C3                        [576, 576, 2]
#   9                -1  1   3982848  models.common.Conv                      [576, 768, 3, 2]
#  10                -1  2   4134912  models.common.C3                        [768, 768, 2]
#  11                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  12                -1  1    443520  models.common.Conv                      [768, 576, 1, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 8]  1         0  models.common.Concat                    [1]
#  15                -1  2   2658816  models.common.C3                        [1152, 576, 2, False]
#  16                -1  1    221952  models.common.Conv                      [576, 384, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 6]  1         0  models.common.Concat                    [1]
#  19                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  20                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  21                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  22           [-1, 4]  1         0  models.common.Concat                    [1]
#  23                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  24                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  25          [-1, 20]  1         0  models.common.Concat                    [1]
#  26                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  27                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  28          [-1, 16]  1         0  models.common.Concat                    [1]
#  29                -1  2   2437632  models.common.C3                        [768, 576, 2, False]
#  30                -1  1   2987136  models.common.Conv                      [576, 576, 3, 2]
#  31          [-1, 12]  1         0  models.common.Concat                    [1]
#  32                -1  2   4429824  models.common.C3                        [1152, 768, 2, False]
#  33  [23, 26, 29, 32]  1     34632  models.yolo.Detect                      [1, [[19, 27, 44, 40, 38, 94], [96, 68, 86, 152, 180, 137], [140, 301, 303, 264, 238, 542], [436, 615, 739, 380, 925, 792]], [192, 384, 576, 768]]
# Model summary: 379 layers, 35275944 parameters, 35275944 gradients, 49.3 GFLOPs
#
# Transferred 619/627 items from yolov5m6.pt
# AMP: checks passed ✅
# freezing model.0.conv.weight
# freezing model.0.bn.weight
# freezing model.0.bn.bias
# freezing model.1.conv.weight
# freezing model.1.bn.weight
# freezing model.1.bn.bias
# freezing model.2.cv1.conv.weight
# freezing model.2.cv1.bn.weight
# freezing model.2.cv1.bn.bias
# freezing model.2.cv2.conv.weight
# freezing model.2.cv2.bn.weight
# freezing model.2.cv2.bn.bias
# freezing model.2.cv3.conv.weight
# freezing model.2.cv3.bn.weight
# freezing model.2.cv3.bn.bias
# freezing model.2.m.0.cv1.conv.weight
# freezing model.2.m.0.cv1.bn.weight
# freezing model.2.m.0.cv1.bn.bias
# freezing model.2.m.0.cv2.conv.weight
# freezing model.2.m.0.cv2.bn.weight
# freezing model.2.m.0.cv2.bn.bias
# freezing model.2.m.1.cv1.conv.weight
# freezing model.2.m.1.cv1.bn.weight
# freezing model.2.m.1.cv1.bn.bias
# freezing model.2.m.1.cv2.conv.weight
# freezing model.2.m.1.cv2.bn.weight
# freezing model.2.m.1.cv2.bn.bias
# freezing model.3.conv.weight
# freezing model.3.bn.weight
# freezing model.3.bn.bias
# freezing model.4.cv1.conv.weight
# freezing model.4.cv1.bn.weight
# freezing model.4.cv1.bn.bias
# freezing model.4.cv2.conv.weight
# freezing model.4.cv2.bn.weight
# freezing model.4.cv2.bn.bias
# freezing model.4.cv3.conv.weight
# freezing model.4.cv3.bn.weight
# freezing model.4.cv3.bn.bias
# freezing model.4.m.0.cv1.conv.weight
# freezing model.4.m.0.cv1.bn.weight
# freezing model.4.m.0.cv1.bn.bias
# freezing model.4.m.0.cv2.conv.weight
# freezing model.4.m.0.cv2.bn.weight
# freezing model.4.m.0.cv2.bn.bias
# freezing model.4.m.1.cv1.conv.weight
# freezing model.4.m.1.cv1.bn.weight
# freezing model.4.m.1.cv1.bn.bias
# freezing model.4.m.1.cv2.conv.weight
# freezing model.4.m.1.cv2.bn.weight
# freezing model.4.m.1.cv2.bn.bias
# freezing model.4.m.2.cv1.conv.weight
# freezing model.4.m.2.cv1.bn.weight
# freezing model.4.m.2.cv1.bn.bias
# freezing model.4.m.2.cv2.conv.weight
# freezing model.4.m.2.cv2.bn.weight
# freezing model.4.m.2.cv2.bn.bias
# freezing model.4.m.3.cv1.conv.weight
# freezing model.4.m.3.cv1.bn.weight
# freezing model.4.m.3.cv1.bn.bias
# freezing model.4.m.3.cv2.conv.weight
# freezing model.4.m.3.cv2.bn.weight
# freezing model.4.m.3.cv2.bn.bias
# freezing model.5.conv.weight
# freezing model.5.bn.weight
# freezing model.5.bn.bias
# freezing model.6.cv1.conv.weight
# freezing model.6.cv1.bn.weight
# freezing model.6.cv1.bn.bias
# freezing model.6.cv2.conv.weight
# freezing model.6.cv2.bn.weight
# freezing model.6.cv2.bn.bias
# freezing model.6.cv3.conv.weight
# freezing model.6.cv3.bn.weight
# freezing model.6.cv3.bn.bias
# freezing model.6.m.0.cv1.conv.weight
# freezing model.6.m.0.cv1.bn.weight
# freezing model.6.m.0.cv1.bn.bias
# freezing model.6.m.0.cv2.conv.weight
# freezing model.6.m.0.cv2.bn.weight
# freezing model.6.m.0.cv2.bn.bias
# freezing model.6.m.1.cv1.conv.weight
# freezing model.6.m.1.cv1.bn.weight
# freezing model.6.m.1.cv1.bn.bias
# freezing model.6.m.1.cv2.conv.weight
# freezing model.6.m.1.cv2.bn.weight
# freezing model.6.m.1.cv2.bn.bias
# freezing model.6.m.2.cv1.conv.weight
# freezing model.6.m.2.cv1.bn.weight
# freezing model.6.m.2.cv1.bn.bias
# freezing model.6.m.2.cv2.conv.weight
# freezing model.6.m.2.cv2.bn.weight
# freezing model.6.m.2.cv2.bn.bias
# freezing model.6.m.3.cv1.conv.weight
# freezing model.6.m.3.cv1.bn.weight
# freezing model.6.m.3.cv1.bn.bias
# freezing model.6.m.3.cv2.conv.weight
# freezing model.6.m.3.cv2.bn.weight
# freezing model.6.m.3.cv2.bn.bias
# freezing model.6.m.4.cv1.conv.weight
# freezing model.6.m.4.cv1.bn.weight
# freezing model.6.m.4.cv1.bn.bias
# freezing model.6.m.4.cv2.conv.weight
# freezing model.6.m.4.cv2.bn.weight
# freezing model.6.m.4.cv2.bn.bias
# freezing model.6.m.5.cv1.conv.weight
# freezing model.6.m.5.cv1.bn.weight
# freezing model.6.m.5.cv1.bn.bias
# freezing model.6.m.5.cv2.conv.weight
# freezing model.6.m.5.cv2.bn.weight
# freezing model.6.m.5.cv2.bn.bias
# freezing model.7.conv.weight
# freezing model.7.bn.weight
# freezing model.7.bn.bias
# freezing model.8.cv1.conv.weight
# freezing model.8.cv1.bn.weight
# freezing model.8.cv1.bn.bias
# freezing model.8.cv2.conv.weight
# freezing model.8.cv2.bn.weight
# freezing model.8.cv2.bn.bias
# freezing model.8.cv3.conv.weight
# freezing model.8.cv3.bn.weight
# freezing model.8.cv3.bn.bias
# freezing model.8.m.0.cv1.conv.weight
# freezing model.8.m.0.cv1.bn.weight
# freezing model.8.m.0.cv1.bn.bias
# freezing model.8.m.0.cv2.conv.weight
# freezing model.8.m.0.cv2.bn.weight
# freezing model.8.m.0.cv2.bn.bias
# freezing model.8.m.1.cv1.conv.weight
# freezing model.8.m.1.cv1.bn.weight
# freezing model.8.m.1.cv1.bn.bias
# freezing model.8.m.1.cv2.conv.weight
# freezing model.8.m.1.cv2.bn.weight
# freezing model.8.m.1.cv2.bn.bias
# freezing model.9.conv.weight
# freezing model.9.bn.weight
# freezing model.9.bn.bias
# freezing model.10.cv1.conv.weight
# freezing model.10.cv1.bn.weight
# freezing model.10.cv1.bn.bias
# freezing model.10.cv2.conv.weight
# freezing model.10.cv2.bn.weight
# freezing model.10.cv2.bn.bias
# freezing model.10.cv3.conv.weight
# freezing model.10.cv3.bn.weight
# freezing model.10.cv3.bn.bias
# freezing model.10.m.0.cv1.conv.weight
# freezing model.10.m.0.cv1.bn.weight
# freezing model.10.m.0.cv1.bn.bias
# freezing model.10.m.0.cv2.conv.weight
# freezing model.10.m.0.cv2.bn.weight
# freezing model.10.m.0.cv2.bn.bias
# freezing model.10.m.1.cv1.conv.weight
# freezing model.10.m.1.cv1.bn.weight
# freezing model.10.m.1.cv1.bn.bias
# freezing model.10.m.1.cv2.conv.weight
# freezing model.10.m.1.cv2.bn.weight
# freezing model.10.m.1.cv2.bn.bias
# freezing model.11.cv1.conv.weight
# freezing model.11.cv1.bn.weight
# freezing model.11.cv1.bn.bias
# freezing model.11.cv2.conv.weight
# freezing model.11.cv2.bn.weight
# freezing model.11.cv2.bn.bias
# WARNING ⚠️ --img-size 600 must be multiple of max stride 64, updating to 640
# optimizer: SGD(lr=0.01) with parameter groups 103 weight(decay=0.0), 107 weight(decay=0.0005), 107 bias
# WARNING ⚠️ DP not recommended, use torch.distributed.run for best DDP Multi-GPU results.
# See Multi-GPU Tutorial at https://docs.ultralytics.com/yolov5/tutorials/multi_gpu_training to get started.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /kaggle/working/train/labels... 1608 images, 0 backgrounds, 0 co
# train: New cache created: /kaggle/working/train/labels.cache
# train: Caching images (1.4GB ram): 100%|██████████| 1608/1608 [00:15<00:00, 106.
# val: Scanning /kaggle/working/valid/labels... 321 images, 0 backgrounds, 0 corru
# val: New cache created: /kaggle/working/valid/labels.cache
# val: Caching images (0.3GB ram): 100%|██████████| 321/321 [00:04<00:00, 66.31it/
#
# AutoAnchor: 7.17 anchors/target, 0.994 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to birds/feature_extraction/labels.jpg...
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to birds/feature_extraction
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/39      4.15G     0.1072    0.02643          0        152        640:  WARNING ⚠️ TensorBoard graph visualization failure Sizes of tensors must match except in dimension 1. Expected size 20 but got size 19 for tensor number 1 in the list.
#        0/39      4.67G    0.07794    0.02794          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.764      0.796      0.842      0.427
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/39      12.4G    0.04413    0.02226          0         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.737      0.841      0.854      0.445
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/39      12.4G     0.0395      0.019          0         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.774      0.863      0.887      0.445
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/39      12.4G     0.0357    0.01613          0         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.897      0.953      0.974      0.625
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/39      12.4G    0.03181      0.015          0         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.966      0.962      0.985      0.576
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/39      12.4G    0.02795     0.0141          0         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.985      0.992      0.992      0.677
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/39      12.4G    0.02498    0.01359          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.978      0.982      0.991      0.639
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/39      12.4G     0.0236    0.01301          0         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.989      0.991      0.991      0.738
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/39      12.4G    0.02292    0.01294          0         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.992      0.992      0.752
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/39      12.4G    0.02131    0.01279          0         27        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.991      0.992      0.993      0.798
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/39      12.4G    0.02036    0.01194          0         13        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.804
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/39      12.4G    0.02035    0.01241          0         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.985      0.997      0.993      0.764
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/39      12.4G    0.01893    0.01172          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.991      0.992      0.992      0.806
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/39      12.4G    0.01861    0.01189          0         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.987      0.997      0.992      0.799
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/39      12.4G    0.01774    0.01147          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.994       0.99      0.836
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/39      12.4G    0.01759    0.01147          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.991      0.995      0.991      0.809
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/39      12.4G    0.01694    0.01114          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.995      0.997      0.992      0.835
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/39      12.4G     0.0169    0.01132          0         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321       0.99      0.994      0.989       0.84
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/39      12.4G    0.01627    0.01124          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.997      0.997      0.992      0.823
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/39      12.4G    0.01601    0.01107          0         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.997      0.994      0.992      0.833
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/39      12.4G     0.0159    0.01074          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.991      0.996      0.991      0.823
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/39      12.4G     0.0155    0.01086          0         24        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/39      12.4G    0.01498    0.01037          0         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.851
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/39      12.4G     0.0147    0.01066          0         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.994      0.991      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/39      12.4G    0.01446    0.01048          0         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.995      0.992      0.861
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/39      12.4G    0.01419    0.01013          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.996      0.994      0.992      0.871
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/39      12.4G    0.01369    0.01036          0         27        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.868
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/39      12.4G     0.0138   0.009943          0         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.873
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/39      12.4G    0.01356    0.01004          0         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.875
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/39      12.4G    0.01328     0.0101          0         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.997      0.997      0.993      0.878
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/39      12.4G    0.01319    0.00988          0         19        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.997      0.992      0.877
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/39      12.4G    0.01283   0.009714          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.996      0.994      0.992      0.877
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/39      12.4G    0.01301   0.009978          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.995      0.992      0.885
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/39      12.4G     0.0124   0.009354          0         17        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.997      0.997      0.992      0.884
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/39      12.4G    0.01198   0.009424          0         20        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.997      0.997      0.992      0.888
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/39      12.4G    0.01201   0.009783          0         18        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.882
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/39      12.4G    0.01187   0.009487          0         21        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.997      0.992      0.889
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/39      12.4G    0.01217   0.009711          0         22        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.993      0.997      0.992      0.887
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/39      12.4G    0.01166   0.009386          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.997      0.992      0.893
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/39      12.4G    0.01177   0.009429          0         23        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.997      0.997      0.992      0.888
#
# 40 epochs completed in 0.258 hours.
# Optimizer stripped from birds/feature_extraction/weights/last.pt, 71.1MB
# Optimizer stripped from birds/feature_extraction/weights/best.pt, 71.1MB
#
# Validating birds/feature_extraction/weights/best.pt...
# Fusing layers...
# Model summary: 276 layers, 35248920 parameters, 0 gradients, 48.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        321        321      0.994      0.997      0.992      0.893
# Results saved to birds/feature_extraction

# %%
WEIGHTS_BEST = f"{PROJECT_NAME}/feature_extraction/weights/best.pt"
! python yolov5/val.py --weights $WEIGHTS_BEST --batch $BATCH --data 'data.yaml' --task test --project $PROJECT_NAME --name 'validation_on_test_data' --augment
# Out:
# val: data=data.yaml, weights=['birds/feature_extraction/weights/best.pt'], batch_size=64, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=birds, name=validation_on_test_data, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 276 layers, 35248920 parameters, 0 gradients, 48.9 GFLOPs
# test: Scanning /kaggle/working/test/labels... 81 images, 0 backgrounds, 0 corrup
# test: New cache created: /kaggle/working/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50
#                    all         81         81      0.999          1      0.995       0.91
# Speed: 1.4ms pre-process, 50.0ms inference, 2.3ms NMS per image at shape (64, 3, 640, 640)
# Results saved to birds/validation_on_test_data

# %% [markdown]
# ## Make box on test data

# %%
! python yolov5/detect.py --weights $WEIGHTS_BEST --conf 0.6 --source 'test/images' --project $PROJECT_NAME --name 'detect_test' --augment --line=3
# Out:
# detect: weights=['birds/feature_extraction/weights/best.pt'], source=test/images, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=True, visualize=False, update=False, project=birds, name=detect_test, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 276 layers, 35248920 parameters, 0 gradients, 48.9 GFLOPs
# image 1/81 /kaggle/working/test/images/0014.jpg: 640x512 1 birds, 226.8ms
# image 2/81 /kaggle/working/test/images/0038.jpg: 512x640 1 birds, 203.4ms
# image 3/81 /kaggle/working/test/images/0053.jpg: 448x640 1 birds, 196.2ms
# image 4/81 /kaggle/working/test/images/0071.jpg: 512x640 1 birds, 64.4ms
# image 5/81 /kaggle/working/test/images/0073.jpg: 640x576 1 birds, 197.4ms
# image 6/81 /kaggle/working/test/images/0093.jpg: 512x640 1 birds, 61.7ms
# image 7/81 /kaggle/working/test/images/0100.jpg: 512x640 1 birds, 61.8ms
# image 8/81 /kaggle/working/test/images/0192.jpg: 512x640 1 birds, 61.8ms
# image 9/81 /kaggle/working/test/images/0203.jpg: 448x640 1 birds, 59.3ms
# image 10/81 /kaggle/working/test/images/0205.jpg: 512x640 1 birds, 61.8ms
# image 11/81 /kaggle/working/test/images/0228.jpg: 640x512 1 birds, 47.5ms
# image 12/81 /kaggle/working/test/images/0234.jpg: 448x640 1 birds, 44.8ms
# image 13/81 /kaggle/working/test/images/0237.jpg: 448x640 1 birds, 40.7ms
# image 14/81 /kaggle/working/test/images/0249.jpg: 448x640 1 birds, 34.0ms
# image 15/81 /kaggle/working/test/images/0283.jpg: 512x640 1 birds, 35.9ms
# image 16/81 /kaggle/working/test/images/0294.jpg: 640x576 1 birds, 40.8ms
# image 17/81 /kaggle/working/test/images/0299.jpg: 384x640 1 birds, 143.4ms
# image 18/81 /kaggle/working/test/images/0324.jpg: 640x640 1 birds, 87.1ms
# image 19/81 /kaggle/working/test/images/0379.jpg: 448x640 1 birds, 29.1ms
# image 20/81 /kaggle/working/test/images/0388.jpg: 448x640 1 birds, 30.2ms
# image 21/81 /kaggle/working/test/images/0427.jpg: 512x640 1 birds, 29.4ms
# image 22/81 /kaggle/working/test/images/0466.jpg: 448x640 1 birds, 30.5ms
# image 23/81 /kaggle/working/test/images/0531.jpg: 448x640 1 birds, 30.6ms
# image 24/81 /kaggle/working/test/images/0572.jpg: 512x640 1 birds, 31.2ms
# image 25/81 /kaggle/working/test/images/0598.jpg: 512x640 1 birds, 30.9ms
# image 26/81 /kaggle/working/test/images/0628.jpg: 512x640 1 birds, 30.0ms
# image 27/81 /kaggle/working/test/images/0630.jpg: 512x640 1 birds, 32.9ms
# image 28/81 /kaggle/working/test/images/0637.jpg: 512x640 1 birds, 31.1ms
# image 29/81 /kaggle/working/test/images/0664.jpg: 640x448 1 birds, 199.2ms
# image 30/81 /kaggle/working/test/images/0666.jpg: 448x640 1 birds, 36.0ms
# image 31/81 /kaggle/working/test/images/0699.jpg: 512x640 1 birds, 42.5ms
# image 32/81 /kaggle/working/test/images/0709.jpg: 640x448 1 birds, 41.8ms
# image 33/81 /kaggle/working/test/images/0729.jpg: 512x640 1 birds, 43.7ms
# image 34/81 /kaggle/working/test/images/0741.jpg: 640x448 1 birds, 41.6ms
# image 35/81 /kaggle/working/test/images/0753.jpg: 448x640 1 birds, 36.5ms
# image 36/81 /kaggle/working/test/images/0768.jpg: 512x640 1 birds, 31.4ms
# image 37/81 /kaggle/working/test/images/0789.jpg: 640x512 1 birds, 40.1ms
# image 38/81 /kaggle/working/test/images/0803.jpg: 512x640 1 birds, 33.0ms
# image 39/81 /kaggle/working/test/images/0829.jpg: 640x640 1 birds, 41.8ms
# image 40/81 /kaggle/working/test/images/0867.jpg: 512x640 1 birds, 35.0ms
# image 41/81 /kaggle/working/test/images/0871.jpg: 448x640 1 birds, 31.2ms
# image 42/81 /kaggle/working/test/images/0889.jpg: 640x512 1 birds, 34.3ms
# image 43/81 /kaggle/working/test/images/0901.jpg: 640x384 1 birds, 138.4ms
# image 44/81 /kaggle/working/test/images/0967.jpg: 448x640 1 birds, 28.6ms
# image 45/81 /kaggle/working/test/images/0975.jpg: 448x640 1 birds, 29.7ms
# image 46/81 /kaggle/working/test/images/0980.jpg: 448x640 1 birds, 30.8ms
# image 47/81 /kaggle/working/test/images/1000.jpg: 512x640 1 birds, 31.2ms
# image 48/81 /kaggle/working/test/images/1002.jpg: 448x640 1 birds, 31.0ms
# image 49/81 /kaggle/working/test/images/1063.jpg: 512x640 1 birds, 31.4ms
# image 50/81 /kaggle/working/test/images/1074.jpg: 384x640 1 birds, 31.8ms
# image 51/81 /kaggle/working/test/images/1082.jpg: 640x576 1 birds, 42.1ms
# image 52/81 /kaggle/working/test/images/1085.jpg: 512x640 1 birds, 38.6ms
# image 53/81 /kaggle/working/test/images/1200.jpg: 512x640 1 birds, 38.3ms
# image 54/81 /kaggle/working/test/images/1222.jpg: 512x640 1 birds, 35.3ms
# image 55/81 /kaggle/working/test/images/1274.jpg: 640x512 1 birds, 31.9ms
# image 56/81 /kaggle/working/test/images/1288.jpg: 384x640 1 birds, 29.6ms
# image 57/81 /kaggle/working/test/images/1298.jpg: 512x640 1 birds, 31.4ms
# image 58/81 /kaggle/working/test/images/1401.jpg: 512x640 1 birds, 32.9ms
# image 59/81 /kaggle/working/test/images/1413.jpg: 448x640 1 birds, 29.9ms
# image 60/81 /kaggle/working/test/images/1446.jpg: 640x448 1 birds, 32.8ms
# image 61/81 /kaggle/working/test/images/1468.jpg: 384x640 1 birds, 28.2ms
# image 62/81 /kaggle/working/test/images/1513.jpg: 640x448 1 birds, 30.2ms
# image 63/81 /kaggle/working/test/images/1532.jpg: 640x640 1 birds, 41.4ms
# image 64/81 /kaggle/working/test/images/1585.jpg: 448x640 1 birds, 33.9ms
# image 65/81 /kaggle/working/test/images/1646.jpg: 640x640 1 birds, 38.8ms
# image 66/81 /kaggle/working/test/images/1649.jpg: 640x640 1 birds, 39.8ms
# image 67/81 /kaggle/working/test/images/1674.jpg: 640x640 1 birds, 39.1ms
# image 68/81 /kaggle/working/test/images/1678.jpg: 448x640 1 birds, 29.7ms
# image 69/81 /kaggle/working/test/images/1696.jpg: 640x576 1 birds, 36.2ms
# image 70/81 /kaggle/working/test/images/1703.jpg: 640x576 1 birds, 36.7ms
# image 71/81 /kaggle/working/test/images/1744.jpg: 576x640 1 birds, 143.7ms
# image 72/81 /kaggle/working/test/images/1758.jpg: 448x640 1 birds, 29.8ms
# image 73/81 /kaggle/working/test/images/1781.jpg: 512x640 1 birds, 31.7ms
# image 74/81 /kaggle/working/test/images/1803.jpg: 448x640 1 birds, 31.1ms
# image 75/81 /kaggle/working/test/images/1831.jpg: 448x640 1 birds, 31.5ms
# image 76/81 /kaggle/working/test/images/1849.jpg: 448x640 1 birds, 32.7ms
# image 77/81 /kaggle/working/test/images/1913.jpg: 448x640 1 birds, 31.5ms
# image 78/81 /kaggle/working/test/images/1929.jpg: 512x640 1 birds, 32.4ms
# image 79/81 /kaggle/working/test/images/1935.jpg: 512x640 1 birds, 33.2ms
# image 80/81 /kaggle/working/test/images/1941.jpg: 448x640 1 birds, 31.7ms
# image 81/81 /kaggle/working/test/images/2010.jpg: 448x640 1 birds, 32.0ms
# Speed: 0.4ms pre-process, 51.5ms inference, 2.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to birds/detect_test

# %%
imgs = glob('/kaggle/working/birds/detect_test/*')
choice = np.random.choice(imgs, 15)
for i in choice:
    img = cv2.imread(i)
    plt.figure(figsize=(5, 5))
    plt.imshow(img)
